# %% [markdown]
#                                        NETFLIX DATA CLEANING, ANALYSIS AND VISUALIZATION :---------

# %%
#IMPORTING THE NECESSARY LIBRARIES WHICH I WILL WORK UPON
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as  plt 
from matplotlib import image as mpimg
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import seaborn as sns

# %%
df = pd.read_csv('netflix1.csv')
df                                                         #THE NETFLIX DATA TABLE
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.shape
# Out:
# (8790, 10)

# %% [markdown]
#                                                   | DATA CLEANING AND REPROCESSING |

# %%
#DATA CLEANING AND REPROCESSING STARTS HERE....!!
df.columns = df.columns.str.title() #To convert the column heads into sentence case

# %%
df.head() #To check if the above formatting was successful
# Out:
#   Show_Id     Type                             Title         Director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_Added  Release_Year Rating  Duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            Listed_In
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df['Date_Added'] = pd.to_datetime(df['Date_Added'])  #To change the date-like strings into date-time objects

# %%
df.head() #To check if the above formatting was successful
# Out:
#   Show_Id     Type                             Title         Director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          Country Date_Added  Release_Year Rating  Duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            Listed_In
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
df.info() #Basic information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       8790 non-null   object
#  1   Type          8790 non-null   object
#  2   Title         8790 non-null   object
#  3   Director      8790 non-null   object
#  4   Country       8790 non-null   object
#  5   Date_Added    8790 non-null   datetime64[ns]
#  6   Release_Year  8790 non-null   int64
#  7   Rating        8790 non-null   object
#  8   Duration      8790 non-null   object
#  9   Listed_In     8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 686.8+ KB

# %%
df.tail()
# Out:
#      Show_Id     Type               Title   Director        Country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#      Date_Added  Release_Year Rating   Duration  \
# 8785 2017-01-17          2016  TV-PG  2 Seasons
# 8786 2018-09-13          2016  TV-Y7  3 Seasons
# 8787 2016-12-15          2012  TV-PG   1 Season
# 8788 2018-06-23          2016   TV-Y   1 Season
# 8789 2018-06-07          2016  TV-Y7   1 Season
#
#                                               Listed_In
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
df.columns
# Out:
# Index(['Show_Id', 'Type', 'Title', 'Director', 'Country', 'Date_Added',
#        'Release_Year', 'Rating', 'Duration', 'Listed_In'],
#       dtype='object')

# %%
df.isnull().sum() #To check for null values
# Out:
# Show_Id         0
# Type            0
# Title           0
# Director        0
# Country         0
# Date_Added      0
# Release_Year    0
# Rating          0
# Duration        0
# Listed_In       0
# dtype: int64

# %%
df.duplicated().sum()  #To check for duplicate values
# Out:
# np.int64(0)

# %% [markdown]
#                                                           VISUALIZATIONS

# %%
#VISUALIZING THE NETFLIX DATA USING SEABORN AND MATPLOTLIB LIBRARIES.....!!
type_total_streams = df['Type'].value_counts()
type_total_streams
# Out:
# Type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
#Visualizing the top contents by type: Movies & TV shows 
plt.figure(figsize= (8, 6))
sns.barplot(x=type_total_streams.index, y=type_total_streams.values, color = 'pink')
text_box = plt.title('TOP CONTENTS BY TYPE-- MOVIES AND TV SHOWS', fontdict={'fontsize': 14, 'fontweight': 'bold', 'fontname': 'Trebuchet MS', 'color': 'white'})
text_box.set_bbox(dict(facecolor='red', alpha= 1, edgecolor = 'black'))
logo = mpimg.imread('pngwing1.com.png')
plt.figimage(logo, 0, 0, zorder=0, alpha=0)
imagebox = OffsetImage(logo, zoom= 0.3)
ab = AnnotationBbox(imagebox, (0.5, 1.2), frameon=False, xycoords='axes fraction', boxcoords="axes fraction", pad=0)
plt.gca().add_artist(ab)
plt.xlabel('Type', color = 'red')
plt.ylabel('Total number of streams', color = 'red')
plt.show()

# %%
ratings_on_content = df['Rating'].value_counts()
ratings_on_content
# Out:
# Rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
#Visualizing the ratings based on content 
plt.figure(figsize= (8, 6))
sns.barplot(x=ratings_on_content.index, y=ratings_on_content.values, color = 'red')
text_box = plt.title('RATINGS BASED ON CONTENT:', fontdict={'fontsize': 14, 'fontweight': 'bold', 'fontname': 'Garamond', 'color': 'black'})
text_box.set_bbox(dict(facecolor='red', alpha= 1, edgecolor = 'black'))
logo = mpimg.imread('pngwing.com.png')
plt.figimage(logo, 0, 0, zorder=0, alpha=0)
imagebox = OffsetImage(logo, zoom= 0.2)
ab = AnnotationBbox(imagebox, (0.5, 1.2), frameon=False, xycoords='axes fraction', boxcoords="axes fraction", pad=0)
plt.gca().add_artist(ab)
plt.xlabel('RATINGS', color = 'purple')
plt.ylabel('DISTRIBUTION', color = 'purple')
plt.xticks(rotation = 60)
plt.show()

# %%
#Replacing the 'Not Given' item by 'Unknown'
df['Country'] = df['Country'].replace('Not Given' , 'Unknown')

# %%
#Lets check if the above formatting was successful
countries = df['Country'].value_counts().head(20)
countries
# Out:
# Country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Unknown            287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Mexico             138
# Egypt              123
# Australia          114
# Turkey             112
# Nigeria            105
# Germany            104
# China              100
# Brazil              88
# Taiwan              86
# Indonesia           86
# Name: count, dtype: int64

# %%
#Visualizing the top 20 countries which has streamed netflix contents
plt.figure(figsize = (8, 6))
sns.barplot(x=countries.values, y=countries.index, hue = countries.values, palette = 'bright')
plt.title('TOP 20 COUNTRIES WHICH STREAM NETFLIX CONTENTS [2008-2020]', fontdict={'fontsize': 16, 'fontweight': 'bold',  'fontname': 'Times New Roman', 'color': 'red'})
logo = mpimg.imread('netflix2.png')
plt.figimage(logo, 0, 0, zorder=0, alpha=0)
imagebox = OffsetImage(logo, zoom= 0.35)
ab = AnnotationBbox(imagebox, (0.5, 1.2), frameon=False, xycoords='axes fraction', boxcoords="axes fraction", pad=0)
plt.gca().add_artist(ab)
plt.xlabel('TOTAL CONTENT STREAMED', color = 'red')
plt.ylabel('COUNTRIES', color = 'red')
plt.show()

# %%
df['Genres'] = df['Listed_In'].apply(lambda x: x.split(','))
top_genres = pd.Series(sum(df['Genres'], [])).value_counts().head(5)
top_genres
# Out:
#  International Movies    2624
# Dramas                   1599
# Comedies                 1210
# Action & Adventure        859
# Documentaries             829
# Name: count, dtype: int64

# %%
#Visualizing the top 5 genres streamed in the world 
plt.figure(figsize = (8,6))
sns.barplot(x= top_genres.values, y= top_genres.index, hue = top_genres.index, palette = 'dark:red') 
plt.title('TOP 5 GENRES STREAMED ACROSS THE GLOBE:', fontdict={'fontsize': 17, 'fontweight': 'bold',  'fontname': 'Times New Roman', 'color': 'red'})
logo = mpimg.imread('netflix2.png')
plt.figimage(logo, 0, 0, zorder=0, alpha=0)
imagebox = OffsetImage(logo, zoom= 0.35)
ab = AnnotationBbox(imagebox, (0.5, 1.2), frameon=False, xycoords='axes fraction', boxcoords="axes fraction", pad=0)
plt.gca().add_artist(ab)
plt.xlabel('NUMBER OF STREAMS', color = 'red')
plt.ylabel('GENRES', color = 'red')
plt.show()

# %%
#We need a slight change in here. The topmost director plot is shown by not given which is a bit inconvenient.
#We will change that.
df['Director'] = df['Director'].replace('Not Given' , 'Unknown director')

# %%
#Lets run the value count again. Perfect!
directors = df['Director'].value_counts().head(20)
directors
# Out:
# Director
# Unknown director                2588
# Rajiv Chilaka                     20
# Alastair Fothergill               18
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
# Cathy Garcia-Molina               13
# Jay Chapman                       12
# Martin Scorsese                   12
# Youssef Chahine                   12
# Steven Spielberg                  11
# Mark Thornton, Todd Kauffman      10
# Don Michael Paul                  10
# David Dhawan                       9
# Yılmaz Erdoğan                     8
# Robert Rodriguez                   8
# Johnnie To                         8
# Ryan Polito                        8
# Quentin Tarantino                  8
# Name: count, dtype: int64

# %%
#Visualizing the top 20 most title-winning directors 
plt.figure(figsize= (8, 6))
sns.barplot(x= directors.values, y = directors.index, hue = directors, palette = 'bright')
plt.title('TOP 20 MOST TITLE-WINNING DIRECTORS [2008 - 2020]',  fontdict={'fontsize': 18, 'fontweight': 'bold', 'fontname': 'Times New Roman', 'color': 'red'})
logo = mpimg.imread('pngwing.com.png')
plt.figimage(logo, 0, 0, zorder=0, alpha=0)
imagebox = OffsetImage(logo, zoom= 0.16)
ab = AnnotationBbox(imagebox, (0.5, 1.2), frameon=False, xycoords='axes fraction', boxcoords="axes fraction", pad=0)
plt.gca().add_artist(ab)
plt.xlabel('NUMBER OF TITLES WON', color = 'red')
plt.ylabel('NAME OF DIRECTORS',color = 'red')
plt.show()

# %%
years = df['Year_Added'] = df['Date_Added'].dt.year #To seperate years from the given dates.

# %%
year_addons = df['Year_Added'].value_counts().sort_index()
year_addons
# Out:
# Year_Added
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      11
# 2014      24
# 2015      82
# 2016     426
# 2017    1185
# 2018    1648
# 2019    2016
# 2020    1879
# 2021    1498
# Name: count, dtype: int64

# %%
#Visualizing the annual yearly trends in content add-ons
plt.figure(figsize =(8,6))
sns.lineplot(x = year_addons.index , y = year_addons.values, marker = 'o', color = 'blue')
text_box= plt.title('THE ANNUAL YEARLY TRENDS BASED ON CONTENT ADD-ON:', fontweight = 'bold', fontsize = 12, color = 'black' )
text_box.set_bbox(dict(facecolor='red', alpha= 1, edgecolor = 'red'))
logo = mpimg.imread('pngwing1.com.png')
plt.figimage(logo, 0, 0, zorder=0, alpha=0)
imagebox = OffsetImage(logo, zoom= 0.2)
ab = AnnotationBbox(imagebox, (0.5, 1.2), frameon=False, xycoords='axes fraction', boxcoords="axes fraction", pad=0)
plt.gca().add_artist(ab)
plt.xlabel('YEARS HAVING ADD-ONs', color= 'red')
plt.ylabel('FREQUENCY OF CONTENTS', color = 'red')
plt.grid(True)
plt.show()

# %%
df['Month_Added'] = df['Date_Added'].dt.month

# %%
month_addons = df['Month_Added'].value_counts().sort_index()
month_addons
# Out:
# Month_Added
# 1     737
# 2     562
# 3     741
# 4     763
# 5     632
# 6     728
# 7     827
# 8     754
# 9     769
# 10    760
# 11    705
# 12    812
# Name: count, dtype: int64

# %%
#Visualizing the monthly content add-ons 
plt.figure(figsize =(8,6))
sns.barplot(x= month_addons.index, y= month_addons.values, hue=month_addons, palette = 'pastel', legend=False)
text_box= plt.title('THE MONTHLY TRENDS BASED ON CONTENT ADD-ON:', fontweight = 'bold', fontsize = 12, color = 'black' )
text_box.set_bbox(dict(facecolor='red', alpha= 1, edgecolor = 'red'))
logo = mpimg.imread('pngwing.com.png')
plt.figimage(logo, 0, 0, zorder=0, alpha=0)
imagebox = OffsetImage(logo, zoom= 0.15)
ab = AnnotationBbox(imagebox, (0.5, 1.2), frameon=False, xycoords='axes fraction', boxcoords="axes fraction", pad=0)
plt.gca().add_artist(ab)
plt.xlabel('MONTHS', color= 'red')
plt.ylabel('FREQUENCY OF CONTENT ADD-ONs', color = 'red')
plt.xticks(range(1, 13), ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
plt.show()

# %% [markdown]
#                  THANK YOU!! I HOPE THE VISUALIZATIONS WERE INSIGHTFUL AND CATCHING!! NOW, NETFLIX AND CHILL :)
